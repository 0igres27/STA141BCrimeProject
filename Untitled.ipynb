# %%
import requests
import pandas as pd
import time

BASE_URL = "https://api.v1.citizenrims.com/api/v1/Case"

headers = {
    "Authorization": "Bearer PASTE_YOUR_TOKEN_HERE",
    "Accept": "application/json",
    "Referer": "https://davis.citizenrims.com/",
    "Origin": "https://davis.citizenrims.com",
    "User-Agent": "Mozilla/5.0"
}

params = {
    "agencyId": 914,
    "primaryAgencyId": 914,
    "startDate": "Thu Jan 01 2026",
    "endDate": "Mon Feb 23 2026",
    "circleLatitude": 0,
    "circleLongitude": 0,
    "circleRadius": 0,
    "types": (
        "N90Z,N200,N13,N90A,N510,N220,N250,N90B,N90C,N90D,"
        "N35,N270,N210,N90F,N26,N39,N09,N64,N100,N23,N90G,"
        "N240,N90H,N370,N40,N120,N11,N36,N280,N90J,N290,N520"
    ),
    "page": 1,
    "pageSize": 500
}

all_rows = []

while True:
    r = requests.get(BASE_URL, headers=headers, params=params)

    if r.status_code != 200:
        print("Stopped at page", params["page"], "status:", r.status_code)
        break

    data = r.json()
    if not data:
        break

    all_rows.extend(data)
    print(f"Fetched page {params['page']} ({len(data)} rows)")

    params["page"] += 1
    time.sleep(0.3)

df = pd.DataFrame(all_rows)
print("Total rows:", len(df))
# Out:
# Stopped at page 1 status: 401
# Total rows: 0

# %%
r = requests.get(BASE_URL, headers=headers, params=params)
print(r.status_code)
print(r.text[:500])
# Out:
# 401

# %%
import requests

BASE_URL = "https://api.v1.citizenrims.com/api/v1/Case"

headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIjoiQ2l0aXplbiIsImp0aSI6IjhmNDI0NDQ1LWU5OWEtNDcwZi04ZjU2LThmMjVlMzVjYmYyNCIsImFhYyI6IjAiLCJhZ2VuY3lJZCI6IjAiLCJuYmYiOjE3NzE5MDUyODIsImV4cCI6MTc3MTk5MTY4MiwiaWF0IjoxNzcxOTA1MjgyfQ.7zCXVrj9HlyWKhLaW0Sa6d7Oc_GrCRYrnwyjIAR_V44",
    "Accept": "application/json, text/plain, */*",
    "Origin": "https://davis.citizenrims.com",
    "Referer": "https://davis.citizenrims.com/",
    "User-Agent": "Mozilla/5.0"
}

params = {
    "agencyId": 914,
    "primaryAgencyId": 914,
    "startDate": "Sun Feb 01 2026",
    "endDate": "Mon Feb 23 2026",
    "circleLatitude": 0,
    "circleLongitude": 0,
    "circleRadius": 0,
    "types": (
        "N90Z,N200,N13,N90A,N510,N220,N250,N90B,N90C,"
        "N90D,N35,N270,N210,N90F,N26,N39,N09,N64,N100,"
        "N23,N90G,N240,N90H,N370,N40,N120,N11,N36,N280,"
        "N90J,N290,N520"
    ),
    "page": 1,
    "pageSize": 25
}

r = requests.get(BASE_URL, headers=headers, params=params)

print("Status:", r.status_code)
print("First 300 chars:")
print(r.text[:300])
# Out:
# Status: 200
# First 300 chars:
# [{"id":4243216,"caseNumber":"26-00425","originalCaseNumber":12600425,"agencyId":914,"reportDate":"2026-02-01T00:00:00","offenseCode1":"11364(A) HS","offenseCode2":"11350(A) HS","offenseCode3":"","offenseCode4":"","offenseCode5":"","offenseCode6":"","offenseDescription1":"Possess unlawful paraphernal

# %%
all_cases = []
page = 1

while True:
    params["page"] = page
    r = requests.get(BASE_URL, headers=headers, params=params)

    data = r.json()
    if not data:
        break

    all_cases.extend(data)
    print(f"Fetched page {page}, total rows: {len(all_cases)}")
    page += 1
# Out:
# Fetched page 1, total rows: 72
# Fetched page 2, total rows: 144
# Fetched page 3, total rows: 216
# Fetched page 4, total rows: 288
# Fetched page 5, total rows: 360
# Fetched page 6, total rows: 432
# Fetched page 7, total rows: 504
# Fetched page 8, total rows: 576
# Fetched page 9, total rows: 648
# Fetched page 10, total rows: 720
# Fetched page 11, total rows: 792
# Fetched page 12, total rows: 864
# Fetched page 13, total rows: 936
# Fetched page 14, total rows: 1008
# Fetched page 15, total rows: 1080
# Fetched page 16, total rows: 1152
# Fetched page 17, total rows: 1224
# Fetched page 18, total rows: 1296
# Fetched page 19, total rows: 1368
# Fetched page 20, total rows: 1440
# Fetched page 21, total rows: 1512
# Fetched page 22, total rows: 1584
# Fetched page 23, total rows: 1656
# Fetched page 24, total rows: 1728
# Fetched page 25, total rows: 1800
# Fetched page 26, total rows: 1872
# Fetched page 27, total rows: 1944
# Fetched page 28, total rows: 2016
# ...
